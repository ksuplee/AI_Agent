# %% [markdown]
# # 03 Hugging Face 모델 활용 LLM 이해
#
# ## 03-3 실습: 텍스트생성·번역·요약
#
# ### 03-3-2 실습환경 준비
#
# #### (1) Colab 실행하기
# #### (2) Transformer 설치하기

# %%
# Hugging Face transformers 라이브러리 설치
# -q 옵션: 설치 로그를 간단히 표시
# !pip install transformers -q

# %% [markdown]
# #### (3) Transformer 버전 확인하기

# %%
# transformers 라이브러리 불러오기
import transformers

# 현재 설치된 transformers 버전 출력
# (4.30 이상 권장)
print("Transformers version:", transformers.__version__)
# Out:
# Transformers version: 4.57.3

# %% [markdown]
# #### (4) Hugging Face 토큰 발급 및 Colab 보안 저장소에 추가
#
# 1.  **Hugging Face 웹사이트에서 토큰 발급**: Hugging Face (huggingface.co) 에 로그인하여 `Settings` -> `Access Tokens` 페이지에서 새 토큰을 생성합니다. (권한은 `read` 이상으로 설정).
# 2.  **Colab 보안 저장소에 추가**: Colab 환경에서 왼쪽 패널의 '🔑' 아이콘(비밀번호 모양)을 클릭하여 `Secret` 탭을 엽니다. `New secret` 버튼을 클릭하여 `Name`에 `HF_TOKEN`을 입력하고, `Value`에 Hugging Face에서 발급받은 토큰 값을 붙여넣습니다. 그리고 'Notebook access'를 켜주세요.

# %% [markdown]
# #### (5) 코드에서 Hugging Face 토큰 사용하기
#
# 이제 Colab 보안 저장소에 저장된 `HF_TOKEN`을 코드에서 불러와 Hugging Face에 로그인할 수 있습니다. 아래 코드를 실행해 주세요.

# %%
from huggingface_hub import login
from google.colab import userdata

# Colab 보안 저장소에서 HF_TOKEN 불러오기
hf_token = userdata.get('HF_TOKEN')


# Hugging Face 로그인
login(token=hf_token)

print("Hugging Face에 성공적으로 로그인했습니다!")
# Out:
# Hugging Face에 성공적으로 로그인했습니다!

# %% [markdown]
# ### 03-3-3 Text Generation 실습
# > Task: 문장을 이어 쓰는 텍스트 생성(Text Generation)
#
# #### (1) GPT-2 기반 텍스트 생성
# - 실행 코드

# %%
from transformers import pipeline

# (1) 텍스트 생성 파이프라인 생성
# - task: "text-generation"
# - model: GPT-2 (사전학습된 생성 모델)
generator = pipeline(
    task="text-generation",
    model="gpt2"
)

# (2) 프롬프트(시작 문장) 정의
prompt = "Artificial Intelligence will change"

# (3) 텍스트 생성 실행
# max_length: 생성될 전체 문장 길이
# num_return_sequences: 생성 결과 개수
result = generator(
    prompt,
    max_length=50,
    num_return_sequences=1
)

# (4) 결과 출력
print("=== 생성 결과 ===\n")
print(result[0]["generated_text"])
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성 결과 ===
#
# Artificial Intelligence will change the way we think about technology, and the way we think about technology in general. It will change how we evaluate and use technology. It will change the way we think about how the world really works. It will change how we think about technologies. It will change how we think about the future of our lives, and how we think about technology in general.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in the technology itself, but in what we have learned from previous generations of thinkers on this topic.
#
# The future of the world is not in

# %% [markdown]
# - 실행 후 관찰하기
#     - 문장이 자연스럽게 이어지는가?
#     - 문맥 오류나 반복이 발생하는가?
#     - 프롬프트를 “Artificial Intelligence will change education” 등으로 바꿔보면 결과가 어떻게 달라질까?

# %%
from transformers import pipeline

# (1) 텍스트 생성 파이프라인 생성
# - task: "text-generation"
# - model: GPT-2 (사전학습된 생성 모델)
generator = pipeline(
    task="text-generation",
    model="gpt2"
)

# (2) 프롬프트(시작 문장) 정의
prompt = "Artificial Intelligence will change education"

# (3) 텍스트 생성 실행
# max_length: 생성될 전체 문장 길이
# num_return_sequences: 생성 결과 개수
result = generator(
    prompt,
    max_length=50,
    num_return_sequences=1
)

# (4) 결과 출력
print("=== 생성 결과 ===\n")
print(result[0]["generated_text"])
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성 결과 ===
#
# Artificial Intelligence will change education and the way people think about the world. It's going to change how we think about the world, and how we think about other people's lives, too.
#
# It's going to change our ability to learn. It's going to make learning more and more complex. It's going to change how we think about the world.
#
# It's going to change how we think about people's lives. It's going to make learning more and more complex.
#
# It's going to change how we think about the world.
#
# It's going to change how we think about other people's lives. It's going to make learning more and more complex.
#
# If you're not smart enough to do something, then you're not doing it. If you're smart enough to do something, then you're not doing it.
#
# This is what they're talking about. It's not going to be good, it's not going to be good. It's going to be good. It's going to be good.
#
# Because it's going to be good. Because it's going to be good.
#
# So they're talking about a very, very large, very big problem. And they're talking about a very, very large,

# %% [markdown]
# ### 02-3-4 Translation 실습
# > Task: 영어 문장을 한국어로 번역 (또는 그 반대)
#
# #### (1) Helsinki-NLP 번역 모델 사용
# - 실행 코드

# %% [markdown]
# 이제 `Helsinki-NLP/opus-mt-ko-en`와 같은 모델을 문제없이 다운로드하고 사용할 수 있습니다. 번역 코드를 다시 실행해 보세요.

# %%
from transformers import pipeline

# (1) 번역 파이프라인 생성
# 한국어 → 영어 번역 모델 지정
translator = pipeline(
    task="translation",
    # model="chunwoolee0/mt5_small_bongsoo_en_ko"
    model="Helsinki-NLP/opus-mt-ko-en"
)

# (2) 번역할 한국어 문장 입력
# text = "AI will change education and society."
text = "인공지능은 교육과 사회를 변화시킬 것입니다."


# (3) 번역 실행
result = translator(
    text,
    max_length=100
)

# (4) 번역 결과 출력
# print("=== 번역 결과 (영어 -> 한국어) ===\n")
print("=== 번역 결과 (한국어 -> 영어) ===\n")
print(result[0]["translation_text"])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/842k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu
# === 번역 결과 (한국어 -> 영어) ===
#
# AI will change education and society.

# %% [markdown]
# - 실습 응용
#     - 입력 문장을 바꿔보세요: "AI will transform our daily life in the next decade."
#     - 번역 방향 변경 (한국어 → 영어): "Helsinki-NLP/opus-mt-ko-en" 모델로 변경
# > Tip: Hugging Face Hub에서 “translation” 태그로 더 다양한 언어쌍 모델을 찾을 수 있음

# %%
from transformers import pipeline

# (1) 번역 파이프라인 생성
# 한국어 → 영어 번역 모델 지정
translator = pipeline(
    task="translation",
    model="chunwoolee0/mt5_small_bongsoo_en_ko"
    # model="Helsinki-NLP/opus-mt-ko-en"
)

# (2) 번역할 한국어 문장 입력
text = "AI will change education and society."
# text = "인공지능은 교육과 사회를 변화시킬 것입니다."


# (3) 번역 실행
result = translator(
    text,
    max_length=100
)

# (4) 번역 결과 출력
print("=== 번역 결과 (영어 -> 한국어) ===\n")
# print("=== 번역 결과 (한국어 -> 영어) ===\n")
print(result[0]["translation_text"])
# Out:
# config.json:   0%|          | 0.00/821 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/303 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# Device set to use cpu
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 번역 결과 (영어 -> 한국어) ===
#
# AI가 교육과 사회를 변화시키고 있다.

# %% [markdown]
# ### 03-3-5 Summarization 실습
# - Task: 긴 문장을 요약 (Text Summarization)
#
# #### (1) 예제 코드: BART 요약 모델
# - 실행 코드

# %%
from transformers import pipeline

# (1) 요약 파이프라인 생성
# CNN 뉴스 요약에 Fine-tuned된 BART 모델
summarizer = pipeline(
    task="summarization",
    model="facebook/bart-large-cnn"
)

# (2) 요약할 원문 텍스트
text = """
Artificial intelligence (AI) is rapidly changing the world.
It is being used in education, healthcare, and industry to improve efficiency and accuracy.
However, there are also ethical challenges such as privacy and bias.
"""

# (3) 요약 실행
# max_length: 요약 최대 길이
# min_length: 요약 최소 길이
# do_sample=False: 결과를 안정적으로 생성
result = summarizer(
    text,
    max_length=50,
    min_length=20,
    do_sample=False
)

# (4) 요약 결과 출력
print("=== 요약 결과 ===\n")
print(result[0]["summary_text"])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Your max_length is set to 50, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# === 요약 결과 ===
#
# Artificial intelligence (AI) is rapidly changing the world. It is being used in education, healthcare, and industry to improve efficiency. There are also ethical challenges such as privacy and bias.

# %% [markdown]
# - 실습 응용
#     - 직접 기사나 뉴스 텍스트를 붙여넣어  요약해보기
#     - max_length, min_length 값을 바꿔서 결과 비교
# - 관찰하기
#     - 짧게 요약할수록 정보가 손실되었는가?
#     - 요약 내용이 원문과 일치하는가?
#
# ### 03-3-5 실습 요약
#
# | Task | 처리 방식 | 결과 성격 |
# | ---- | ----- | ----- |
# | 생성   | 문장 확장 | 창의적   |
# | 번역   | 언어 변환 | 의미 보존 |
# | 요약   | 정보 압축 | 핵심 중심 |
#
# > **같은 입력이라도 Task에 따라 AI의 “사고 방식”은 완전히 달라진다.**
