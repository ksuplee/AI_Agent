# %% [markdown]
# <a href="https://colab.research.google.com/github/ksuplee/AI_Agent/blob/main/01_3_%EC%9E%90%EA%B8%B0%EC%86%8C%EA%B0%9C_Agent_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01-3 자기소개 AI Agent 실습
# ---
# ## 학습목표
# - Hugging Face `transformers` 라이브러리를 활용하여 간단한 **텍스트 생성 모델**을 실행할 수 있다.
# - LLM을 이용해 **자기소개 문장을 자동 생성**할 수 있다.
# - **Prompt 작성 방식에 따라 출력이 어떻게 달라지는지** 경험할 수 있다.
#
# ---
# ## 들어가며
# > 여러분이라면 AI Agent가 자기소개를 대신한다면, 어떤 내용을 포함하고 싶나요?
#
# 예시:
# - 이름, 전공, 취미, 관심 분야
# - 장래희망, 성격, 가치관 등
# ---

# %% [markdown]
# ## 01-3-1 실습 환경 준비

# %%
# ✅ 필수 라이브러리 설치
# !pip install transformers -q

# %% [markdown]
# 💡 **Tip**
# - Python 3.9 이상 권장 (3.10~3.11 호환)
# - IDE: VSCode, Jupyter Notebook, Colab 등
# - Colab을 사용할 경우, 반드시 첫 실행 셀에 위 명령어를 입력해야 합니다.

# %% [markdown]
# ## 01-3-2 기본 실습: 영어 자기소개 생성
# > 영어 모델 GPT-2를 사용하여 자기소개 문장을 자동 생성해보기

# %%
from transformers import pipeline

# 텍스트 생성 파이프라인 생성
generator = pipeline("text-generation", model="gpt2")

# 자기소개 프롬프트 입력1
prompt = "My name is Hong Gil-dong. I am a student majoring in AI. My hobby is"
result = generator(prompt, max_length=60, num_return_sequences=1)

print("=== 생성된 영어 자기소개 1 ===\n")
print(result[0]['generated_text'])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성된 영어 자기소개 ===
#
# My name is Hong Gil-dong. I am a student majoring in AI. My hobby is creating robots. I am a part of the AI-controlled robot project. I am currently doing development work for the first batch of AI bot modules. I am also working on the first batch of AI bot modules that will allow you to create your own robot. You can download the project to your computer or to the Android app store. I will be posting more information soon.
#
# You can find more information about this project on the project forums.
#
# Thank you for your support on our platform.
#
# Source:
#
# http://www.techcrunch.com/forum/index.php/topic,1668.0.1
#
# We are really excited about the project!
#
# You can also check out the news here:

# %%
# 자기소개 프롬프트 입력 2
prompt = "My name is Hong Gil-dong. I am a student majoring in AI. My hobby is traveling and listening music. Please write a short self-introduction in a friendly tone."
result = generator(prompt, max_length=60, num_return_sequences=1)

print("=== 생성된 영어 자기소개 2 ===\n")
print(result[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성된 영어 자기소개 2 ===
#
# My name is Hong Gil-dong. I am a student majoring in AI. My hobby is traveling and listening music. Please write a short self-introduction in a friendly tone. in a short self. That's going name in Hong Gil-dong. As one the fast course. Seeing there and believing good. How you want to dangerous! ( believing good! ) he let him! ( this is him! ) he fast course in a magic cover. As one the spirit when you want to have to don't what was barve finish. As one the fast course in a short self when you want to don't what was barve finish. How you want to don't what was barve finish. As one the fast course in a short self! ( there is him! ) he was barve finish. How you want to don't w

# %% [markdown]
# 📌 **생각해보기**
# - GPT-2는 문장을 자연스럽게 이어가지만, 문맥 연결이 완벽하지 않을 수 있습니다.
# - 영어 문장 완성 능력을 관찰하며 LLM의 생성 특성을 이해해봅시다.
# ---

# %% [markdown]
# ## 01-3-3 심화 실습: 한국어 자기소개 생성
# > 한국어 전용 모델 **KoGPT2 (skt/kogpt2-base-v2)** 를 사용하여 실습

# %%
from transformers import pipeline

# 한국어 텍스트 생성 파이프라인
generator = pipeline("text-generation", model="skt/kogpt2-base-v2")

# 한국어 프롬프트 입력 1
prompt = "안녕하세요. 제 이름은 홍길동이고, 인공지능을 전공하고 있습니다. 제 취미는 독서와 음악 감상입니다. 저는"
result = generator(prompt, max_length=80, num_return_sequences=1)

print("=== 생성된 한국어 자기소개 1 ===\n")
print(result[0]['generated_text'])
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성된 한국어 자기소개 ===
#
# 안녕하세요. 제 이름은 홍길동이고, 인공지능을 전공하고 있습니다. 제 취미는 독서와 음악 감상입니다. 저는 음악을 좋아하고 음악을 잘 몰라서 그런지 음악을 듣는 편이라고 합니다."
# "예. 저도 저를 좋아합니다."
# "음~ 홍길동이라는 이름은 저에게 어울리지 않는 이름입니다. 하지만 저의 친구 중에는 저를 좋아하는 사람도 있습니다. 저는 홍길동씨가 저와 함께 음악을 하고 있기에 제가 좋아하는 사람입니다."
# "흠흠흠. 네?"
# "저는 홍길동이란 이름으로 작곡도 하고 있다고 들었습니다. 그분도 저를 좋아하십니다."
# "아, 아~ 저도 이제 홍길동씨가 저를 좋아한다고 들었습니다. 홍길동씨가 저를 좋아할지는 모르지만 저희의 친구 중에는 홍길동씨가 저를 좋아한다고 들었습니다. 그런데 홍길동씨가 저를 좋아하는 이유는 뭘까요?"
# "홍길동씨를 좋아하는 이유는 뭐예요? 홍길동씨가 저를 좋아한다고 들었습니다."
# "홍길동씨가 저를 좋아한다고 들었습니다. 그런데 홍길동씨는 왜 저를 좋아하지 않는 것일까요?"
# "어떻게 하면 저를 좋아하는지 모르지만 홍길동씨가 저를 좋아하는 이유는 뭘까요?"
# "우선 저를 좋아하는 이유는 뭘까요?"
# "홍길동씨를 좋아하는 이유가

# %%
# 한국어 프롬프트 입력 2
prompt = """
너는 나의 개인비서야.
아래 정보를 참고하여 나를 대신해서 공식 자기소개문을 작성해줘.

안녕하세요.
제 이름은 홍길동이고, 인공지능을 전공하고 있습니다.
제 취미는 독서와 음악 감상입니다.
"""

result = generator(prompt, max_length=80, num_return_sequences=1)

print("=== 생성된 한국어 자기소개 2 ===\n")
print(result[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 생성된 한국어 자기소개 2 ===
#
#
# 너는 나의 개인비서야.
# 아래 정보를 참고하여 나를 대신해서 공식 자기소개문을 작성해줘.
#
# 안녕하세요.
# 제 이름은 홍길동이고, 인공지능을 전공하고 있습니다.
# 제 취미는 독서와 음악 감상입니다.
#
#
# 제가 좋아하는 책만 골라서 읽어드리면 도움이 됩니다.
# 제가 좋아하는 책만 골라서 읽어드리는거죠!
# 이벤트에 참가하면
# 아이디어 상품권을
# 많이 받을 수 있습니다~~
# 저는 책을 좋아합니다.
# 아이디어는 바로 회사생활이니까.
# 요즘은 책 읽는데 돈도 많이 들지만,
# 좋은 책을 많이 읽어드리고 싶습니다.
# 안녕하세요. 얼마전만해도 ``나도 #빵순이``라는 말이 나왔을때마다 기분이 안좋았던 기억이 있는데,
# 진짜 #빵순이
# #빵순이 #빵지순례 #빵스타그램 #일상 #일상스타그램 #소통 #좋아요
# #food #foodstagram #instafood #맞팔 #선팔 #instadaily #dailylook #dailyfood #foodstagram #instalike #foodporn #foodie #foodgasm #f4f #l4l #follow #followme #dailyfor

# %% [markdown]
# ### 🔍 실습에서 확인할 사항
# - 출력 결과에 **비문, 반복 문장, 불완전 문장**이 포함될 수 있음
# - Prompt를 조금만 수정해도 결과가 크게 달라짐
#
# | 프롬프트 | 결과 특징 |
# |-----------|------------|
# | “제 취미는” | 불완전 문장으로 끝나는 경우 많음 |
# | “제 취미는 독서와 음악 감상입니다. 저는” | 자연스럽게 자기소개 이어짐 |
# | “친구들에게 소개하듯이 자연스럽게 자기소개를 해줘” | 대화체로 변환됨 |
#
# ➡️ **Prompt 설계가 모델의 출력 품질을 결정합니다.**

# %% [markdown]
# ## 01-3-4 응용 실습 아이디어

# %% [markdown]
# | 상황 | 예시 프롬프트 |
# |------|----------------|
# | **면접용** | “면접관에게 인사하는 자기소개를 작성해줘. 진지하고 전문적인 어조로.” |
# | **친구 소개용** | “친근하고 유머러스한 자기소개를 만들어줘.” |
# | **SNS 프로필용** | “3문장으로 나를 표현하는 자기소개를 써줘.” |
# | **이력서용** | “이력서에 적을 자기소개를 형식적으로 작성해줘.” |

# %%
# prompt = "친근하고 유머러스하게 자기소개를 작성해줘."
prompt = """
너는 나의 개인비서야.
아래 정보를 참고하여 나를 대신해서 친근하고 유머러스하게 자기소개문을 작성해줘.

안녕하세요.
제 이름은 홍길동이고, 인공지능을 전공하고 있습니다.
제 취미는 독서와 음악 감상입니다.
"""
result = generator(prompt, max_length=100, num_return_sequences=1)

print("=== 변형 프롬프트 자기소개 ===\n")
print(result[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# === 변형 프롬프트 자기소개 ===
#
#
# 너는 나의 개인비서야.
# 아래 정보를 참고하여 나를 대신해서 친근하고 유머러스하게 자기소개문을 작성해줘.
#
# 안녕하세요.
# 제 이름은 홍길동이고, 인공지능을 전공하고 있습니다.
# 제 취미는 독서와 음악 감상입니다.
# 특히 음악감상을 하면서 저의 꿈을 키우게 돼요.
# 이미 저의 꿈을 꾸고 있다고 생각합니다.
# (웃음) 이 글이 좋은 글이 될 거라고 생각합니다.
# 제 꿈은 제가 아닌 다른 사람이 되는 겁니다.
# 이 글을 읽고 저의 꿈을 키우기 위해 여러분의 도움과 도움을 부탁드립니다.
# 자랑스럽게 써주십시오.
# (웃음) 부탁드립니다.
# (웃음) 오늘은 어떤 사람이
# 요즘
# #미소천사 #강아지 #반려견 #강아지스타그램 #멍스타그램 #개스타그램 #펫스타그램 #폼스타그램 #포메라니안 #화이트포메 #댕댕이 #강아지 #반려견 #일상 #pomeranian #pomstagram #petstagram #dog #dogstagram #puppy #instadog #子犬 #犬 #い #こい #メラアン #부산 #수제맥주 #아이스비어 #아이스배달 #아이스비비큐 #맥주

# %% [markdown]
# 💬 **활동 제안**:
# 서로 다른 프롬프트를 만들어 실행한 뒤,
# “어떤 표현이 가장 자연스러운가?”를 비교해보세요.
